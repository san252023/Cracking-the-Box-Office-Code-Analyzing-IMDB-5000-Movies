# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_movies=pd.read_csv('tmdb_5000_movies.csv')
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df_movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df_movies.shape
# Out:
# (4803, 20)

# %%
df_movies.isnull().mean()
# Out:
# budget                  0.000000
# genres                  0.000000
# homepage                0.643556
# id                      0.000000
# keywords                0.000000
# original_language       0.000000
# original_title          0.000000
# overview                0.000625
# popularity              0.000000
# production_companies    0.000000
# production_countries    0.000000
# release_date            0.000208
# revenue                 0.000000
# runtime                 0.000416
# spoken_languages        0.000000
# status                  0.000000
# tagline                 0.175724
# title                   0.000000
# vote_average            0.000000
# vote_count              0.000000
# dtype: float64

# %%
df_movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df_movies['revenue'].isnull().mean()
# Out:
# 0.0

# %%
# %matplotlib inline

# %%
df_movies['revenue'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_movies['runtime'].describe()
# Out:
# count    4801.000000
# mean      107.634035
# std        20.675982
# min        14.000000
# 25%        94.000000
# 50%       104.000000
# 75%       118.000000
# max       338.000000
# Name: runtime, dtype: float64

# %%
median_runtime = df_movies[df['runtime'] > 0]['runtime'].median()

# Replace runtime of 0 with the median runtime
df_movies['runtime'] = df_movies['runtime'].replace(0, median_runtime)
# Out:
# C:\Users\vsan0\AppData\Local\Temp\ipykernel_11196\633157581.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   median_runtime = df_movies[df['runtime'] > 0]['runtime'].median()

# %%
df_movies['runtime'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
'''Runtimes between 14 and 65 minutes are classified as "Very Short".
Runtimes between 66 and 100 minutes are classified as "Short".
Runtimes between 101 and 110 minutes are classified as "Medium".
Runtimes between 111 and 200 minutes are classified as "Long".
Runtimes between 201 and 338 minutes are classified as "Very Long".'''
# Out:
# 'Runtimes between 14 and 65 minutes are classified as "Very Short".\nRuntimes between 66 and 100 minutes are classified as "Short".\nRuntimes between 101 and 110 minutes are classified as "Medium".\nRuntimes between 111 and 200 minutes are classified as "Long".\nRuntimes between 201 and 338 minutes are classified as "Very Long".'

# %%
# Define bin edges and labels
runtime_bin_edges = [14, 66, 100, 111, 200, 338]
runtime_bin_names = ['Very Short', 'Short', 'Medium', 'Long', 'Very Long']

# Create a new column 'Runtime_level' with bin labels
df_movies['Runtime_level'] = pd.cut(df_movies['runtime'], bins=runtime_bin_edges, labels=runtime_bin_names)

# Display the DataFrame with the new column
print(df_movies.head())
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
f,ax = plt.subplots(1, figsize=(10,8))
df_movies['Runtime_level'].value_counts().plot.bar(color=['blue', 'orange','green','red','yellow'])
ax.set_ylabel('Movies Count');
ax.set_xlabel('Runtime Levels')
ax.set_xticklabels(df_movies.Runtime_level.value_counts().index, rotation = 45);
ax.set_title('Movies Count of each Runtime level', y=1.02)
# Out:
# Text(0.5, 1.02, 'Movies Count of each Runtime level')

# %%
df_movies['Runtime_level']
# Out:
# 0        Long
# 1        Long
# 2        Long
# 3        Long
# 4        Long
#         ...
# 4798    Short
# 4799    Short
# 4800     Long
# 4801    Short
# 4802    Short
# Name: Runtime_level, Length: 4803, dtype: category
# Categories (5, object): ['Very Short' < 'Short' < 'Medium' < 'Long' < 'Very Long']

# %%
run_stats = df_movies.groupby('Runtime_level')[['revenue', 'vote_average']].mean()
run_stats
# Out:
#                     revenue  vote_average
# Runtime_level
# Very Short     4.501948e+06      6.172727
# Short          5.153155e+07      5.707982
# Medium         6.457560e+07      6.059339
# Long           1.337728e+08      6.593180
# Very Long      1.190191e+08      7.246667

# %%
ax1,ax2= run_stats.plot.bar(subplots=True,color=['blue','red',])
fig = ax1.get_figure()
fig.set_size_inches(10, 10)

# %%
'''. In general, movies that have Long and Very long  Runtimes (greater than 110 minutes) earns higher Revenue, more popular and critically acclaimed.
2. As the Runtime increases the movies tends to earn higher Revenue, higher popularity and critical acclaim
3. It should be noted that, movies with Runtime (greater than 110 minutes) beats other movies in terms of Revenue by a significant margin.'''

# %%
value = df_movies.loc[1, 'genres']

# %%
value
# Out:
# '[{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]'

# %%
import ast



# Convert string representations of lists into actual lists of dictionaries
df_movies['genres'] = df_movies['genres'].apply(ast.literal_eval)

# Extracting only the names from the 'genres' column
names = df_movies['genres'].apply(lambda x: [entry['name'] for entry in x])

print(names)
# Out:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
#                             ...
# 4798                        [Action, Crime, Thriller]
# 4799                                [Comedy, Romance]
# 4800               [Comedy, Drama, Romance, TV Movie]
# 4801                                               []
# 4802                                    [Documentary]
# Name: genres, Length: 4803, dtype: object

# %%
df_movies['EntireGenre']=names

# %%
df_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1     300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2     245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3     250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...         ...                                                ...
# 4798     220000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4799       9000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 4800          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4801          0                                                 []
# 4802          0                [{'id': 99, 'name': 'Documentary'}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import numpy as np

# Assuming 'EntireGenre' contains lists of genres
df_movies['Genre_count'] = df_movies['EntireGenre'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)

# Print the DataFrame with the new 'Genre_count' column

# %%
df_movies['Genre_count']
# Out:
# 0       4
# 1       3
# 2       3
# 3       4
# 4       3
#        ..
# 4798    3
# 4799    2
# 4800    4
# 4801    0
# 4802    1
# Name: Genre_count, Length: 4803, dtype: int64

# %%
df[['original_title','Genre_count']]
# Out:
#                                 original_title  Genre_count
# 0                                       Avatar          4.0
# 1     Pirates of the Caribbean: At World's End          3.0
# 2                                      Spectre          3.0
# 3                        The Dark Knight Rises          4.0
# 4                                  John Carter          3.0
# ...                                        ...          ...
# 9601                                       NaN          NaN
# 9602                                       NaN          NaN
# 9603                                       NaN          NaN
# 9604                                       NaN          NaN
# 9605                                       NaN          NaN
#
# [9606 rows x 2 columns]

# %%
genre_count_stats = df_movies.groupby('Genre_count')[['revenue', 'vote_average']].mean()

genre_count_stats
# Out:
#                   revenue  vote_average
# Genre_count
# 0            5.974036e+04      2.335714
# 1            4.312003e+07      5.951111
# 2            5.818465e+07      6.124899
# 3            1.068545e+08      6.178689
# 4            1.230421e+08      6.186950
# 5            1.311816e+08      6.109091
# 6            1.124874e+08      5.757576
# 7            3.551932e+07      5.850000

# %%
ax1,ax2 = genre_count_stats.plot.bar(subplots=True)
fig = ax1.get_figure()
fig.set_size_inches(10,10)
ax1.set_ylabel("revenue")
ax1.legend("")
ax1.set_title("")
ax2.set_ylabel("vote_average")
ax2.legend("")
ax2.set_title("")
# Out:
# Text(0.5, 1.0, '')

# %%
"""the number of movie genres increase the revenue but there is slight edge over it"""

# %%
best_genre_combo = df[df['Genre_count'] == 3]
best_genre_combo
# Out:
#            budget                                             genres  \
# 1     300000000.0  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 4     260000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000.0  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 7     280000000.0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 4784          0.0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4788      12000.0  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4794          0.0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4796       7000.0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000.0  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                                homepage        id  \
# 1          http://disney.go.com/disneypictures/pirates/     285.0
# ...

# %%
print(df_movies['revenue'].isnull().sum())
print(df_movies['vote_average'].isnull().sum())
# Out:
# 0
# 0

# %%
# Convert lists to strings
df_movies['EntireGenre'] = df_movies['EntireGenre'].apply(lambda x: ', '.join(x))

# %%
df_movies['EntireGenre']
# Out:
# 0       Action, Adventure, Fantasy, Science Fiction
# 1                        Adventure, Fantasy, Action
# 2                          Action, Adventure, Crime
# 3                    Action, Crime, Drama, Thriller
# 4                Action, Adventure, Science Fiction
#                            ...
# 4798                        Action, Crime, Thriller
# 4799                                Comedy, Romance
# 4800               Comedy, Drama, Romance, TV Movie
# 4801
# 4802                                    Documentary
# Name: EntireGenre, Length: 4803, dtype: object

# %%
best_genre_combo = df_movies.groupby('EntireGenre')[['revenue', 'vote_average']].mean()

best_genre_combo
# Out:
#                                                          revenue  vote_average
# EntireGenre
#                                                     5.974036e+04      2.335714
# Action                                              1.227577e+08      5.609524
# Action, Adventure                                   1.718497e+08      5.787500
# Action, Adventure, Animation, Comedy, Family        2.781528e+08      5.300000
# Action, Adventure, Animation, Comedy, Family, F...  0.000000e+00      6.400000
# ...                                                          ...           ...
# Western, Comedy                                     1.195000e+08      7.200000
# Western, Drama                                      1.721426e+06      6.100000
# Western, Drama, Adventure, Thriller                 5.329505e+08      7.300000
# Western, History                                    1.579519e+07      6.600000
# Western, History, War                               2.581996e+07      5.800000
#
# ...

# %%
plt.figure(figsize=(10,10))
ax = best_genre_combo['revenue'].sort_values(ascending=False).head(5).plot.bar(color=['blue', 'orange','green','red','yellow'])

ax.set_ylabel('revenue')
# Out:
# Text(0, 0.5, 'revenue')

# %%
#BEST GENRE MOVIE IN TERMS OF REVENUE IS :FAMILY,FANTASY AND ADVENTURE

# %%
#best genre combo in terms of vote_average

# %%
plt.figure(figsize=(10,10))
ax = best_genre_combo['vote_average'].sort_values(ascending=False).head(5).plot.barh(color=['blue', 'orange','green','red','yellow'])
ax.set_xlabel('vote_average')
# Out:
# Text(0.5, 0, 'vote_average')

# %%
#BEST GENRE MOVIE IN TERMS OF REVENUE IS :WESTERN,ACTION,DRAMA,HISTORY
